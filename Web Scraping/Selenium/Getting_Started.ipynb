# %%
import requests
from bs4 import BeautifulSoup

link = 'https://www.youtube.com/@GeeksforGeeksVideos/videos'

# %%
resp = requests.get(link)

# %%
soup = BeautifulSoup(resp.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all('a')[0]
# Out:
# <a href="/" style="display: none;" title="YouTube"><svg class="external-icon" id="yt-logo-updated-svg" viewbox="0 0 90 20"><g id="yt-logo-updated" preserveaspectratio="xMidYMid meet" viewbox="0 0 90 20"><g><path d="M27.9727 3.12324C27.6435 1.89323 26.6768 0.926623 25.4468 0.597366C23.2197 2.24288e-07 14.285 0 14.285 0C14.285 0 5.35042 2.24288e-07 3.12323 0.597366C1.89323 0.926623 0.926623 1.89323 0.597366 3.12324C2.24288e-07 5.35042 0 10 0 10C0 10 2.24288e-07 14.6496 0.597366 16.8768C0.926623 18.1068 1.89323 19.0734 3.12323 19.4026C5.35042 20 14.285 20 14.285 20C14.285 20 23.2197 20 25.4468 19.4026C26.6768 19.0734 27.6435 18.1068 27.9727 16.8768C28.5701 14.6496 28.5701 10 28.5701 10C28.5701 10 28.5677 5.35042 27.9727 3.12324Z" fill="#FF0000"></path><path d="M11.4253 14.2854L18.8477 10.0004L11.4253 5.71533V14.2854Z" fill="white"></path></g><g><g id="youtube-paths"><path d="M34.6024 13.0036L31.3945 1.41846H34.1932L35.3174 6.6701C35.6043 7.96361 35.8136 9.06662 35.95 9.97913H36.0323C36.
# ...

# %% [markdown]
# ## Selenium

# %%
# !pip install selenium
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 149.8 kB/s eta 0:01:02
# ...

# %%
# !pip install chromedriver_binary
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for chromedriver_binary: filename=chromedriver_binary-131.0.6747.0.0-py3-none-any.whl size=8860352 sha256=dd788bd0b58aeafa9c0a4c11375ec34174d5cd78706ba90fbc3354a53709712b
#   Stored in directory: c:\users\sanket kadam\appdata\local\pip\cache\wheels\2a\a4\b3\cece5d49cef397becb2f56f650f5cb5519fe9f431e43291bba
# Successfully built chromedriver_binary
# ...

# %%
from selenium import webdriver
import chromedriver_binary

# %%
chromedriver_binary.chromedriver_filename
# Out:
# 'c:\\Users\\Sanket Kadam\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\chromedriver_binary\\chromedriver.exe'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Path to ChromeDriver
chrome_driver_path = 'c://Users//Sanket Kadam//AppData//Local//Programs//Python//Python312//Lib//site-packages//chromedriver_binary//chromedriver.exe'

# Create a Service object
service = Service(executable_path=chrome_driver_path)

# Initialize the WebDriver with the Service object
driver = webdriver.Chrome(service=service)
